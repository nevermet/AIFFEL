# %% [markdown]
# ## E23. Movielens 영화 SBR

# %%
from pathlib import Path
import pandas as pd
import numpy as np

data_path = Path(os.getenv('HOME')+'/aiffel/yoochoose-data/ml-1m') 
train_path = data_path / 'ratings.dat'

def load_data(data_path: Path, nrows=None):
    data = pd.read_csv(data_path, sep='::', header=None, usecols=[0, 1, 2, 3], dtype={0: np.int32, 1: np.int32, 2: np.int32}, nrows=nrows)
    data.columns = ['UserId', 'ItemId', 'Rating', 'Time']
    return data

data = load_data(train_path, None)
data.sort_values(['UserId', 'Time'], inplace=True)  # data를 id와 시간 순서로 정렬해줍니다.
data
# Out:
# /home/aiffel/anaconda3/envs/aiffel/lib/python3.7/site-packages/ipykernel_launcher.py:9: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#   if __name__ == '__main__':
#          UserId  ItemId  Rating       Time
# 31            1    3186       4  978300019
# 22            1    1270       5  978300055
# 27            1    1721       4  978300055
# 37            1    1022       5  978300055
# 24            1    2340       3  978300103
# ...         ...     ...     ...        ...
# 1000019    6040    2917       4  997454429
# 999988     6040    1921       4  997454464
# 1000172    6040    1784       3  997454464
# 1000167    6040     161       3  997454486
# 1000042    6040    1221       4  998315055
#
# [1000209 rows x 4 columns]

# %%
data_path = Path(os.getenv('HOME') + '/aiffel/yoochoose-data/ml-1m')
train_path = data_path / 'ratings.dat'

def load_data(data_path: Path, nrows=None):
    data =pd.read_csv(data_path, sep='::', header=None, usecols=[0, 1, 2, 3], dtype={0: np.int32, 1: np.int32, 2: np.int32}, nrows=nrows)
    data.columns = ['UserId', 'ItemId', 'Rating', 'Time']
    return data

data = load_data(train_path, None)
data.sort_values(['UserId', 'Time'], inplace=True)
data
# Out:
# /home/aiffel/anaconda3/envs/aiffel/lib/python3.7/site-packages/ipykernel_launcher.py:5: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#   """
#          UserId  ItemId  Rating       Time
# 31            1    3186       4  978300019
# 22            1    1270       5  978300055
# 27            1    1721       4  978300055
# 37            1    1022       5  978300055
# 24            1    2340       3  978300103
# ...         ...     ...     ...        ...
# 1000019    6040    2917       4  997454429
# 999988     6040    1921       4  997454464
# 1000172    6040    1784       3  997454464
# 1000167    6040     161       3  997454486
# 1000042    6040    1221       4  998315055
#
# [1000209 rows x 4 columns]
