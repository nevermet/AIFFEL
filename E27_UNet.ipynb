# %% [markdown]
# ## 27. U-Net 성능 개선해 보기

# %%
from __future__ import absolute_import, division
from __future__ import print_function, unicode_literals

import os
import time
import shutil
import functools

import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import matplotlib as mpl
mpl.rcParams['axes.grid'] = False
mpl.rcParams['figure.figsize'] = (12, 12)

from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix
import matplotlib.image as mpimg
import pandas as pd
from PIL import Image
from IPython.display import clear_output

import tensorflow as tf
import tensorflow_addons as tfa
print(tf.__version__)

from tensorflow.keras import layers
from tensorflow.keras import losses
from tensorflow.keras import models
# Out:
# 2.3.0

# %% [markdown]
# ### Step 1. 데이터셋 구성

# %%
img_dir = os.path.join(DATASET_PATH, "train")
label_dir = os.path.join(DATASET_PATH, "train_labels")

# %%
x_train_filenames = [os.path.join(img_dir, filename) for filename in os.listdir(img_dir)]
x_train_filenames.sort()
y_train_filenames = [os.path.join(label_dir, filename) for filename in os.listdir(label_dir)]
y_train_filenames.sort()

# %%
x_train_filenames, x_test_filenames, y_train_filenames, y_test_filenames = \
                    train_test_split(x_train_filenames, y_train_filenames, test_size=0.2)

# %%
num_train_examples = len(x_train_filenames)
num_test_examples = len(x_test_filenames)

print("Number of training examples: {}".format(num_train_examples))
print("Number of test examples: {}".format(num_test_examples))
# Out:
# Number of training examples: 480
# Number of test examples: 120

# %%
display_num = 5

r_choices = np.random.choice(num_train_examples, display_num)

plt.figure(figsize=(10, 15))
for i in range(0, display_num * 2, 2):
    img_num = r_choices[i // 2]
    x_pathname = x_train_filenames[img_num]
    y_pathname = y_train_filenames[img_num]

    plt.subplot(display_num, 2, i + 1)
    plt.imshow(Image.open(x_pathname))
    plt.title("Original Image")

    example_labels = Image.open(y_pathname)
    label_vals = np.unique(example_labels)

    plt.subplot(display_num, 2, i + 2)
    plt.imshow(example_labels)
    plt.title("Masked Image")
    
plt.suptitle("Examples of Images and their Masks")
plt.show()

# %%
# Set hyperparameters

image_size = 256
img_shape = (image_size, image_size, 3)
batch_size = 8
max_epochs = 50

# %%
def _process_pathnames(fname, label_path):
    # We map this function onto each pathname pair
    img_str = tf.io.read_file(fname)
    img = tf.image.decode_bmp(img_str, channels=3) # RGB

    label_img_str = tf.io.read_file(label_path)
    label_img = tf.image.decode_bmp(label_img_str, channels=1) # BMP 0,1

    resize = [image_size, image_size]
    img = tf.image.resize(img, resize)
    label_img = tf.image.resize(label_img, resize)

    scale = 1 / 255.
    img = tf.cast(img, dtype=tf.float32) * scale
    label_img = tf.cast(label_img, dtype=tf.float32) * scale

    return img, label_img

# %%
def shift_img(output_img, label_img, width_shift_range, height_shift_range):
    """This fn will perform the horizontal or vertical shift"""
    if width_shift_range or height_shift_range:
        if width_shift_range:
                width_shift_range = tf.random.uniform([],
                                                  -width_shift_range * img_shape[1],
                                                  width_shift_range * img_shape[1])
        if height_shift_range:
                height_shift_range = tf.random.uniform([],
                                                   -height_shift_range * img_shape[0],
                                                   height_shift_range * img_shape[0])
        output_img = tfa.image.translate(output_img,
                                         [width_shift_range, height_shift_range])
        label_img = tfa.image.translate(label_img,
                                        [width_shift_range, height_shift_range])
    return output_img, label_img

# %%
def flip_img(horizontal_flip, tr_img, label_img):
    if horizontal_flip:
        flip_prob = tf.random.uniform([], 0.0, 1.0)
        tr_img, label_img = tf.cond(tf.less(flip_prob, 0.5),
                                lambda: (tf.image.flip_left_right(tr_img), tf.image.flip_left_right(label_img)),
                                lambda: (tr_img, label_img))
    return tr_img, label_img

# %%
def _augment(img,
             label_img,
             resize=None,  # Resize the image to some size e.g. [256, 256]
             scale=1,  # Scale image e.g. 1 / 255.
             hue_delta=0.,  # Adjust the hue of an RGB image by random factor
             horizontal_flip=True,  # Random left right flip,
             width_shift_range=0.05,  # Randomly translate the image horizontally
             height_shift_range=0.05):  # Randomly translate the image vertically 
    if resize is not None:
        # Resize both images
        label_img = tf.image.resize(label_img, resize)
        img = tf.image.resize(img, resize)
  
    if hue_delta:
        img = tf.image.random_hue(img, hue_delta)
  
    img, label_img = flip_img(horizontal_flip, img, label_img)
    img, label_img = shift_img(img, label_img, width_shift_range, height_shift_range)
    label_img = tf.cast(label_img, dtype=tf.float32) * scale
    img = tf.cast(img, dtype=tf.float32) * scale
    return img, label_img

# %%
def get_baseline_dataset(filenames,
                         labels,
                         preproc_fn=functools.partial(_augment),
                         threads=4,
                         batch_size=batch_size,
                         is_train=True):
    num_x = len(filenames)
    # Create a dataset from the filenames and labels
    dataset = tf.data.Dataset.from_tensor_slices((filenames, labels))
    # Map our preprocessing function to every element in our dataset, taking
    # advantage of multithreading
    dataset = dataset.map(_process_pathnames, num_parallel_calls=threads)

    if is_train:# 학습을 진행할시에만 위에 augment를 진행합니다.
        #if preproc_fn.keywords is not None and 'resize' not in preproc_fn.keywords:
        #  assert batch_size == 1, "Batching images must be of the same size"
        dataset = dataset.map(preproc_fn, num_parallel_calls=threads)
        dataset = dataset.shuffle(num_x * 10)

    dataset = dataset.batch(batch_size)
    return dataset

# %%
train_dataset = get_baseline_dataset(x_train_filenames, # 학습 데이터
                                     y_train_filenames) # 정답 데이터
train_dataset = train_dataset.repeat()
test_dataset = get_baseline_dataset(x_test_filenames,
                                    y_test_filenames,
                                    is_train=False)
train_dataset
# Out:
# <RepeatDataset shapes: ((None, 256, 256, 3), (None, 256, 256, 1)), types: (tf.float32, tf.float32)>

# %%
for images, labels in train_dataset.take(1):
    # Running next element in our graph will produce a batch of images
    plt.figure(figsize=(10, 10))
    img = images[0]

    plt.subplot(1, 2, 1)
    plt.imshow(img)

    plt.subplot(1, 2, 2)
    plt.imshow(labels[0, :, :, 0])
    plt.show()

# %% [markdown]
# ### Pre Step 2. 기존 모델 결과 확인

# %%
# inputs: [batch_size, 256, 256, 3]
encoder = tf.keras.Sequential(name='encoder')

# conv-batchnorm-activation-maxpool
encoder.add(layers.Conv2D(64, (3, 3), padding='same'))
encoder.add(layers.BatchNormalization())
encoder.add(layers.Activation('relu'))
encoder.add(layers.Conv2D(64, (3, 3), strides=2, padding='same'))
encoder.add(layers.BatchNormalization())
encoder.add(layers.Activation('relu')) # conv1: [batch_size, 128, 128, 64]

encoder.add(layers.Conv2D(128, (3, 3), padding='same'))
encoder.add(layers.BatchNormalization())
encoder.add(layers.Activation('relu'))
encoder.add(layers.Conv2D(128, (3, 3), strides=2, padding='same'))
encoder.add(layers.BatchNormalization())
encoder.add(layers.Activation('relu')) # conv2: [batch_size, 64, 64, 128]

encoder.add(layers.Conv2D(256, (3, 3), padding='same'))
encoder.add(layers.BatchNormalization())
encoder.add(layers.Activation('relu'))
encoder.add(layers.Conv2D(256, (3, 3), strides=2, padding='same'))
encoder.add(layers.BatchNormalization())
encoder.add(layers.Activation('relu')) # conv3: [batch_size, 32, 32, 256]

encoder.add(layers.Conv2D(512, (3, 3), padding='same'))
encoder.add(layers.BatchNormalization())
encoder.add(layers.Activation('relu'))
encoder.add(layers.Conv2D(512, (3, 3), strides=2, padding='same'))
encoder.add(layers.BatchNormalization())
encoder.add(layers.Activation('relu')) # conv4-outputs: [batch_size, 16, 16, 512]

# %%
# Encoder 제대로 만들어졌는지 확인

bottleneck = encoder(tf.random.normal([batch_size, 256, 256, 3]))
print(bottleneck.shape)   # (batch_size, 16, 16, 512) 이 나오는지 확인
# Out:
# (8, 16, 16, 512)

# %%
# inputs: [batch_size, 16, 16, 512]
decoder = tf.keras.Sequential(name='decoder')

# conv_transpose-batchnorm-activation
decoder.add(layers.Conv2DTranspose(256, (3, 3), strides=2, padding='same'))
decoder.add(layers.BatchNormalization())
decoder.add(layers.Activation('relu')) # conv_transpose1: [batch_size, 32, 32, 256]
decoder.add(layers.Conv2D(256, (3, 3), padding='same'))
decoder.add(layers.BatchNormalization())
decoder.add(layers.Activation('relu'))

decoder.add(layers.Conv2DTranspose(128, (3, 3), strides=2, padding='same'))
decoder.add(layers.BatchNormalization())
decoder.add(layers.Activation('relu')) # conv_transpose2: [batch_size, 64, 64, 128]
decoder.add(layers.Conv2D(128, (3, 3), padding='same'))
decoder.add(layers.BatchNormalization())
decoder.add(layers.Activation('relu'))

decoder.add(layers.Conv2DTranspose(64, (3, 3), strides=2, padding='same'))
decoder.add(layers.BatchNormalization())
decoder.add(layers.Activation('relu')) # conv_transpose3: [batch_size, 128, 128, 64]
decoder.add(layers.Conv2D(64, (3, 3), padding='same'))
decoder.add(layers.BatchNormalization())
decoder.add(layers.Activation('relu'))

decoder.add(layers.Conv2DTranspose(32, (3, 3), strides=2, padding='same'))
decoder.add(layers.BatchNormalization())
decoder.add(layers.Activation('relu')) # conv transpose4-outputs: [batch_size, 256, 256, 32]
decoder.add(layers.Conv2D(32, (3, 3), padding='same'))
decoder.add(layers.BatchNormalization())
decoder.add(layers.Activation('relu'))

decoder.add(layers.Conv2DTranspose(1, 1, strides=1, padding='same', activation='sigmoid'))

# %%
# decoder 제대로 만들어졌는지 확인

predictions = decoder(bottleneck)
print(predictions.shape)    # (batch_size, 256, 256, 1) 이 나오는지 확인
# Out:
# (8, 256, 256, 1)

# %%
ed_model = tf.keras.Sequential()

ed_model.add(encoder)
ed_model.add(decoder)

# %%
class Conv(tf.keras.Model):
    def __init__(self, num_filters, kernel_size):
        super(Conv, self).__init__()
        self.conv = layers.Conv2D(num_filters, kernel_size, padding='same')
        self.bn = layers.BatchNormalization()

    def call(self, inputs, training=True):
        x = self.conv(inputs)
        x = self.bn(x, training=training)
        x = layers.ReLU()(x)

        return x

# %%
class ConvBlock(tf.keras.Model):
    def __init__(self, num_filters):
        super(ConvBlock, self).__init__()
        self.conv1 = Conv(num_filters, 3)
        self.conv2 = Conv(num_filters * 2, 3)

    def call(self, inputs, training=True):
        encoder = self.conv1(inputs, training=training)
        encoder = self.conv2(encoder, training=training)

        return encoder

class ConvBlock_R(tf.keras.Model):
    def __init__(self, num_filters):
        super(ConvBlock_R, self).__init__()
        self.conv1 = Conv(num_filters, 3)
        self.conv2 = Conv(num_filters, 3)

    def call(self, inputs, training=True):
        decoder = self.conv1(inputs, training=training)
        decoder = self.conv2(decoder, training=training)

        return decoder

class EncoderBlock(tf.keras.Model):
    def __init__(self, num_filters):
        super(EncoderBlock, self).__init__()
        self.conv_block = ConvBlock(num_filters)
        self.encoder_pool = layers.MaxPool2D()

    def call(self, inputs, training=True):
        encoder = self.conv_block(inputs, training=training)
        encoder_pool = self.encoder_pool(encoder)

        return encoder_pool, encoder


class DecoderBlock(tf.keras.Model):
    def __init__(self, num_filters):
        super(DecoderBlock, self).__init__()
        self.convT = layers.Conv2DTranspose(num_filters, 3, strides=2, padding='same')
        self.bn = layers.BatchNormalization()
        self.conv_block_r = ConvBlock_R(num_filters)

    def call(self, input_tensor, concat_tensor, training=True):
        decoder = self.convT(input_tensor)            
        decoder = self.bn(decoder, training=training)
        decoder = layers.ReLU()(decoder)
        decoder = tf.concat([decoder, concat_tensor], axis=-1)
        decoder = self.conv_block_r(decoder, training=training)

        return decoder

# %%
class UNet(tf.keras.Model):
    def __init__(self):
        super(UNet, self).__init__()
        self.encoder_block1 = EncoderBlock(64)
        self.encoder_block2 = EncoderBlock(128)
        self.encoder_block3 = EncoderBlock(256)
        self.encoder_block4 = EncoderBlock(512)

        self.center = ConvBlock(1024)

        self.decoder_block4 = DecoderBlock(512)
        self.decoder_block3 = DecoderBlock(256)
        self.decoder_block2 = DecoderBlock(128)
        self.decoder_block1 = DecoderBlock(64)

        self.output_conv = layers.Conv2D(1, 1, activation='sigmoid')

    def call(self, inputs, training=True):
        encoder1_pool, encoder1 = self.encoder_block1(inputs)
        encoder2_pool, encoder2 = self.encoder_block2(encoder1_pool)
        encoder3_pool, encoder3 = self.encoder_block3(encoder2_pool)
        encoder4_pool, encoder4 = self.encoder_block4(encoder3_pool)

        center = self.center(encoder4_pool)

        decoder4 = self.decoder_block4(center, encoder4)
        decoder3 = self.decoder_block3(decoder4, encoder3)
        decoder2 = self.decoder_block2(decoder3, encoder2)
        decoder1 = self.decoder_block1(decoder2, encoder1)

        outputs = self.output_conv(decoder1)

        return outputs

# %%
unet_model = UNet()

# %%
def dice_coeff(y_true, y_pred):
    smooth = 1e-10
    # Flatten
    y_true_f = tf.reshape(y_true, [-1])
    y_pred_f = tf.reshape(y_pred, [-1])
    intersection = tf.reduce_sum(y_true_f * y_pred_f)
    score = (2. * intersection + smooth) / (tf.reduce_sum(tf.square(y_true_f)) + \
                                            tf.reduce_sum(tf.square(y_pred_f)) + smooth)

    return score

# %%
def dice_loss(y_true, y_pred):
    loss = 1 - dice_coeff(y_true, y_pred)
    return loss

# %%
def bce_dice_loss(y_true, y_pred):
    loss = tf.reduce_mean(losses.binary_crossentropy(y_true, y_pred)) + \
          dice_loss(y_true, y_pred)
    return loss

# %%
optimizer = tf.keras.optimizers.Adam() # 기본 Learning rate 사용

# %%
# 위에서 구성한 두가지 모델 중에서 하나를 선택해 주세요. 
# 여기서 선택을 바꾸어 다른 모델의 학습도 진행해 볼 수 있습니다. 

#print('select the Encoder-Decoder model')
#model = ed_model
#checkpoint_dir =os.path.join(DATASET_PATH,'train_ckpt/ed_model')

print('select the U-Net model')
model = unet_model
checkpoint_dir =os.path.join(DATASET_PATH,'train_ckpt/unet_model')
# Out:
# select the U-Net model

# %%
model.compile(optimizer=optimizer, loss=bce_dice_loss, metrics=[dice_loss])
predictions = model(tf.random.normal([batch_size, image_size, image_size, 3]))
print(predictions.shape)
# Out:
# (8, 256, 256, 1)

# %%
model.summary()
# Out:
# Model: "u_net"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# encoder_block (EncoderBlock) multiple                  76416
# _________________________________________________________________
# encoder_block_1 (EncoderBloc multiple                  444288
# _________________________________________________________________
# encoder_block_2 (EncoderBloc multiple                  1773312
# _________________________________________________________________
# encoder_block_3 (EncoderBloc multiple                  7085568
# _________________________________________________________________
# conv_block_7 (ConvBlock)     multiple                  28326912
# _________________________________________________________________
# decoder_block_8 (DecoderBloc multiple                  18882048
# _________________________________________________________________
# decoder_block_9 (DecoderBloc multiple                  3542784
# _________________________________________________________________
# decoder_block_10 (DecoderBlo multiple                  886656
# _________________________________________________________________
# decoder_block_11 (DecoderBlo multiple                  222144
# _________________________________________________________________
# conv2d_64 (Conv2D)           multiple                  65
# =================================================================
# Total params: 61,240,193
# Trainable params: 61,222,529
# Non-trainable params: 17,664
# _________________________________________________________________

# %%
if not os.path.isdir(checkpoint_dir):
    os.makedirs(checkpoint_dir)

cp_callback = tf.keras.callbacks.ModelCheckpoint(checkpoint_dir,
                                                 save_weights_only=True,
                                                 monitor='val_loss',
                                                 mode='auto',
                                                 save_best_only=True,
                                                 verbose=0)

# %%
cos_decay = tf.keras.experimental.CosineDecay(1e-3, 
                                              max_epochs)
lr_callback = tf.keras.callbacks.LearningRateScheduler(cos_decay, verbose=1)

# %%
## Define print function
def print_images():
    for test_images, test_labels in test_dataset.take(1):
        predictions = model(test_images, training=False)

        plt.figure(figsize=(10, 20))
        plt.subplot(1, 3, 1)
        plt.imshow(test_images[0,: , :, :])
        plt.title("Input image")

        plt.subplot(1, 3, 2)
        plt.imshow(test_labels[0, :, :, 0])
        plt.title("Actual Mask")

        plt.subplot(1, 3, 3)
        plt.imshow(predictions[0, :, :, 0])
        plt.title("Predicted Mask")
        plt.show()

# %%
history = model.fit(train_dataset,
                    epochs=max_epochs,    # 50
                    steps_per_epoch=num_train_examples//batch_size,
                    validation_data=test_dataset,
                    validation_steps=num_test_examples//batch_size,
                    callbacks=[cp_callback, lr_callback]
                    )
# Out:
# Epoch 00001: LearningRateScheduler reducing learning rate to tf.Tensor(0.001, shape=(), dtype=float32).
# Epoch 1/50
#  2/60 [>.............................] - ETA: 17s - loss: 1.4759 - dice_loss: 0.7934WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.2309s vs `on_train_batch_end` time: 0.3672s). Check your callbacks.
# 60/60 [==============================] - ETA: 0s - loss: 0.9498 - dice_loss: 0.6928WARNING:tensorflow:Callbacks method `on_test_batch_end` is slow compared to the batch time (batch time: 0.0037s vs `on_test_batch_end` time: 0.1794s). Check your callbacks.
# 60/60 [==============================] - 39s 645ms/step - loss: 0.9498 - dice_loss: 0.6928 - val_loss: 547.7657 - val_dice_loss: 1.0000
#
# Epoch 00002: LearningRateScheduler reducing learning rate to tf.Tensor(0.0009990134, shape=(), dtype=float32).
# Epoch 2/50
# 60/60 [==============================] - 38s 639ms/step - loss: 0.8292 - dice_loss: 0.6353 - val_loss: 9.3387 - val_dice_loss: 0.9391
#
# Epoch 00003: LearningRateScheduler reducing learning rate to tf.Tensor(0.0009960574, shape=(), dtype=float32).
# Epoch 3/50
# 60/60 [==============================] - 38s 629ms/step - loss: 0.6952 - dice_loss: 0.5301 - val_loss: 4.2499 - val_dice_loss: 0.9404
#
# Epoch 00004: LearningRateScheduler reducing learning rate to tf.Tensor(0.0009911436, shape=(), dtype=float32).
# Epoch 4/50
# 60/60 [==============================] - 37s 612ms/step - loss: 0.6356 - dice_loss: 0.4833 - val_loss: 8.5541 - val_dice_loss: 0.8643
#
# Epoch 00005: LearningRateScheduler reducing learning rate to tf.Tensor(0.0009842915, shape=(), dtype=float32).
# Epoch 5/50
# 60/60 [==============================] - 38s 630ms/step - loss: 0.5345 - dice_loss: 0.4052 - val_loss: 1.7507 - val_dice_loss: 0.7833
#
# Epoch 00006: LearningRateScheduler reducing learning rate to tf.Tensor(0.00097552827, shape=(), dtype=float32).
# Epoch 6/50
# 60/60 [==============================] - 37s 611ms/step - loss: 0.4759 - dice_loss: 0.3594 - val_loss: 1.7922 - val_dice_loss: 0.7138
#
# Epoch 00007: LearningRateScheduler reducing learning rate to tf.Tensor(0.00096488826, shape=(), dtype=float32).
# Epoch 7/50
# 60/60 [==============================] - 38s 630ms/step - loss: 0.4207 - dice_loss: 0.3179 - val_loss: 0.4989 - val_dice_loss: 0.3754
#
# Epoch 00008: LearningRateScheduler reducing learning rate to tf.Tensor(0.0009524136, shape=(), dtype=float32).
# Epoch 8/50
# 60/60 [==============================] - 37s 612ms/step - loss: 0.3970 - dice_loss: 0.2991 - val_loss: 1.5438 - val_dice_loss: 0.6859
#
# Epoch 00009: LearningRateScheduler reducing learning rate to tf.Tensor(0.00093815336, shape=(), dtype=float32).
# Epoch 9/50
# 60/60 [==============================] - 38s 629ms/step - loss: 0.3582 - dice_loss: 0.2688 - val_loss: 0.4619 - val_dice_loss: 0.3229
#
# Epoch 00010: LearningRateScheduler reducing learning rate to tf.Tensor(0.000922164, shape=(), dtype=float32).
# Epoch 10/50
# 60/60 [==============================] - 38s 626ms/step - loss: 0.3163 - dice_loss: 0.2363 - val_loss: 0.7458 - val_dice_loss: 0.5243
#
# Epoch 00011: LearningRateScheduler reducing learning rate to tf.Tensor(0.0009045085, shape=(), dtype=float32).
# Epoch 11/50
# 60/60 [==============================] - 38s 633ms/step - loss: 0.2654 - dice_loss: 0.1969 - val_loss: 0.2759 - val_dice_loss: 0.2021
#
# Epoch 00012: LearningRateScheduler reducing learning rate to tf.Tensor(0.0008852567, shape=(), dtype=float32).
# Epoch 12/50
# 60/60 [==============================] - 37s 616ms/step - loss: 0.2680 - dice_loss: 0.1998 - val_loss: 0.3217 - val_dice_loss: 0.2338
#
# Epoch 00013: LearningRateScheduler reducing learning rate to tf.Tensor(0.00086448435, shape=(), dtype=float32).
# Epoch 13/50
# 60/60 [==============================] - 37s 617ms/step - loss: 0.2280 - dice_loss: 0.1686 - val_loss: 0.3435 - val_dice_loss: 0.2630
#
# Epoch 00014: LearningRateScheduler reducing learning rate to tf.Tensor(0.00084227364, shape=(), dtype=float32).
# Epoch 14/50
# 60/60 [==============================] - 37s 618ms/step - loss: 0.2070 - dice_loss: 0.1532 - val_loss: 0.3301 - val_dice_loss: 0.2447
#
# Epoch 00015: LearningRateScheduler reducing learning rate to tf.Tensor(0.00081871205, shape=(), dtype=float32).
# Epoch 15/50
# 60/60 [==============================] - 37s 617ms/step - loss: 0.2133 - dice_loss: 0.1585 - val_loss: 0.4132 - val_dice_loss: 0.2932
#
# Epoch 00016: LearningRateScheduler reducing learning rate to tf.Tensor(0.00079389266, shape=(), dtype=float32).
# Epoch 16/50
# 60/60 [==============================] - 38s 634ms/step - loss: 0.1869 - dice_loss: 0.1380 - val_loss: 0.2088 - val_dice_loss: 0.1549
#
# Epoch 00017: LearningRateScheduler reducing learning rate to tf.Tensor(0.00076791336, shape=(), dtype=float32).
# Epoch 17/50
# 60/60 [==============================] - 37s 611ms/step - loss: 0.1728 - dice_loss: 0.1271 - val_loss: 0.2429 - val_dice_loss: 0.1786
#
# Epoch 00018: LearningRateScheduler reducing learning rate to tf.Tensor(0.0007408768, shape=(), dtype=float32).
# Epoch 18/50
# 60/60 [==============================] - 38s 627ms/step - loss: 0.1526 - dice_loss: 0.1116 - val_loss: 0.1695 - val_dice_loss: 0.1257
#
# Epoch 00019: LearningRateScheduler reducing learning rate to tf.Tensor(0.00071288965, shape=(), dtype=float32).
# Epoch 19/50
# 60/60 [==============================] - 38s 626ms/step - loss: 0.1539 - dice_loss: 0.1131 - val_loss: 0.1479 - val_dice_loss: 0.1070
#
# Epoch 00020: LearningRateScheduler reducing learning rate to tf.Tensor(0.00068406225, shape=(), dtype=float32).
# Epoch 20/50
# 60/60 [==============================] - 38s 628ms/step - loss: 0.1418 - dice_loss: 0.1046 - val_loss: 0.1459 - val_dice_loss: 0.1066
#
# Epoch 00021: LearningRateScheduler reducing learning rate to tf.Tensor(0.0006545085, shape=(), dtype=float32).
# Epoch 21/50
# 60/60 [==============================] - 37s 609ms/step - loss: 0.1347 - dice_loss: 0.0992 - val_loss: 0.3119 - val_dice_loss: 0.2438
#
# Epoch 00022: LearningRateScheduler reducing learning rate to tf.Tensor(0.00062434503, shape=(), dtype=float32).
# Epoch 22/50
# 60/60 [==============================] - 40s 673ms/step - loss: 0.1347 - dice_loss: 0.0994 - val_loss: 0.1413 - val_dice_loss: 0.1024
#
# Epoch 00023: LearningRateScheduler reducing learning rate to tf.Tensor(0.00059369067, shape=(), dtype=float32).
# Epoch 23/50
# 60/60 [==============================] - 40s 672ms/step - loss: 0.1172 - dice_loss: 0.0862 - val_loss: 0.1517 - val_dice_loss: 0.1140
#
# Epoch 00024: LearningRateScheduler reducing learning rate to tf.Tensor(0.00056266657, shape=(), dtype=float32).
# Epoch 24/50
# 60/60 [==============================] - 40s 674ms/step - loss: 0.1010 - dice_loss: 0.0740 - val_loss: 0.1556 - val_dice_loss: 0.1153
#
# Epoch 00025: LearningRateScheduler reducing learning rate to tf.Tensor(0.00053139526, shape=(), dtype=float32).
# Epoch 25/50
# 60/60 [==============================] - 42s 693ms/step - loss: 0.1017 - dice_loss: 0.0753 - val_loss: 0.1364 - val_dice_loss: 0.1011
#
# Epoch 00026: LearningRateScheduler reducing learning rate to tf.Tensor(0.00049999997, shape=(), dtype=float32).
# Epoch 26/50
# 60/60 [==============================] - 38s 633ms/step - loss: 0.0953 - dice_loss: 0.0694 - val_loss: 0.1679 - val_dice_loss: 0.1230
#
# Epoch 00027: LearningRateScheduler reducing learning rate to tf.Tensor(0.0004686048, shape=(), dtype=float32).
# Epoch 27/50
# 60/60 [==============================] - 38s 630ms/step - loss: 0.0888 - dice_loss: 0.0649 - val_loss: 0.1132 - val_dice_loss: 0.0840
#
# Epoch 00028: LearningRateScheduler reducing learning rate to tf.Tensor(0.00043733336, shape=(), dtype=float32).
# Epoch 28/50
# 60/60 [==============================] - 38s 630ms/step - loss: 0.0862 - dice_loss: 0.0630 - val_loss: 0.1113 - val_dice_loss: 0.0818
#
# Epoch 00029: LearningRateScheduler reducing learning rate to tf.Tensor(0.00040630935, shape=(), dtype=float32).
# Epoch 29/50
# 60/60 [==============================] - 38s 630ms/step - loss: 0.0790 - dice_loss: 0.0576 - val_loss: 0.0970 - val_dice_loss: 0.0707
#
# Epoch 00030: LearningRateScheduler reducing learning rate to tf.Tensor(0.00037565507, shape=(), dtype=float32).
# Epoch 30/50
# 60/60 [==============================] - 38s 629ms/step - loss: 0.0769 - dice_loss: 0.0562 - val_loss: 0.0888 - val_dice_loss: 0.0645
#
# Epoch 00031: LearningRateScheduler reducing learning rate to tf.Tensor(0.00034549143, shape=(), dtype=float32).
# Epoch 31/50
# 60/60 [==============================] - 37s 613ms/step - loss: 0.0709 - dice_loss: 0.0518 - val_loss: 0.0992 - val_dice_loss: 0.0723
#
# Epoch 00032: LearningRateScheduler reducing learning rate to tf.Tensor(0.0003159377, shape=(), dtype=float32).
# Epoch 32/50
# 60/60 [==============================] - 37s 612ms/step - loss: 0.0715 - dice_loss: 0.0523 - val_loss: 0.1001 - val_dice_loss: 0.0738
#
# Epoch 00033: LearningRateScheduler reducing learning rate to tf.Tensor(0.00028711034, shape=(), dtype=float32).
# Epoch 33/50
# 60/60 [==============================] - 38s 630ms/step - loss: 0.0671 - dice_loss: 0.0491 - val_loss: 0.0786 - val_dice_loss: 0.0565
#
# Epoch 00034: LearningRateScheduler reducing learning rate to tf.Tensor(0.0002591231, shape=(), dtype=float32).
# Epoch 34/50
# 60/60 [==============================] - 37s 618ms/step - loss: 0.0696 - dice_loss: 0.0513 - val_loss: 0.0796 - val_dice_loss: 0.0573
#
# Epoch 00035: LearningRateScheduler reducing learning rate to tf.Tensor(0.00023208655, shape=(), dtype=float32).
# Epoch 35/50
# 60/60 [==============================] - 37s 616ms/step - loss: 0.0631 - dice_loss: 0.0460 - val_loss: 0.0788 - val_dice_loss: 0.0570
#
# Epoch 00036: LearningRateScheduler reducing learning rate to tf.Tensor(0.00020610739, shape=(), dtype=float32).
# Epoch 36/50
# 60/60 [==============================] - 38s 637ms/step - loss: 0.0585 - dice_loss: 0.0428 - val_loss: 0.0707 - val_dice_loss: 0.0500
#
# Epoch 00037: LearningRateScheduler reducing learning rate to tf.Tensor(0.00018128792, shape=(), dtype=float32).
# Epoch 37/50
# 60/60 [==============================] - 37s 618ms/step - loss: 0.0578 - dice_loss: 0.0423 - val_loss: 0.0732 - val_dice_loss: 0.0524
#
# Epoch 00038: LearningRateScheduler reducing learning rate to tf.Tensor(0.00015772645, shape=(), dtype=float32).
# Epoch 38/50
# 60/60 [==============================] - 37s 617ms/step - loss: 0.0552 - dice_loss: 0.0401 - val_loss: 0.0714 - val_dice_loss: 0.0511
#
# Epoch 00039: LearningRateScheduler reducing learning rate to tf.Tensor(0.0001355157, shape=(), dtype=float32).
# Epoch 39/50
# 60/60 [==============================] - 39s 645ms/step - loss: 0.0553 - dice_loss: 0.0404 - val_loss: 0.0686 - val_dice_loss: 0.0486
#
# Epoch 00040: LearningRateScheduler reducing learning rate to tf.Tensor(0.00011474339, shape=(), dtype=float32).
# Epoch 40/50
# 60/60 [==============================] - 38s 631ms/step - loss: 0.0530 - dice_loss: 0.0386 - val_loss: 0.0678 - val_dice_loss: 0.0480
#
# Epoch 00041: LearningRateScheduler reducing learning rate to tf.Tensor(9.54915e-05, shape=(), dtype=float32).
# Epoch 41/50
# 60/60 [==============================] - 38s 636ms/step - loss: 0.0538 - dice_loss: 0.0393 - val_loss: 0.0691 - val_dice_loss: 0.0490
#
# Epoch 00042: LearningRateScheduler reducing learning rate to tf.Tensor(7.783601e-05, shape=(), dtype=float32).
# Epoch 42/50
# 60/60 [==============================] - 37s 616ms/step - loss: 0.0515 - dice_loss: 0.0375 - val_loss: 0.0701 - val_dice_loss: 0.0499
#
# Epoch 00043: LearningRateScheduler reducing learning rate to tf.Tensor(6.184671e-05, shape=(), dtype=float32).
# Epoch 43/50
# 60/60 [==============================] - 38s 631ms/step - loss: 0.0504 - dice_loss: 0.0367 - val_loss: 0.0654 - val_dice_loss: 0.0461
#
# Epoch 00044: LearningRateScheduler reducing learning rate to tf.Tensor(4.7586444e-05, shape=(), dtype=float32).
# Epoch 44/50
# 60/60 [==============================] - 37s 614ms/step - loss: 0.0508 - dice_loss: 0.0372 - val_loss: 0.0656 - val_dice_loss: 0.0462
#
# Epoch 00045: LearningRateScheduler reducing learning rate to tf.Tensor(3.5111727e-05, shape=(), dtype=float32).
# Epoch 45/50
# 60/60 [==============================] - 38s 631ms/step - loss: 0.0496 - dice_loss: 0.0361 - val_loss: 0.0651 - val_dice_loss: 0.0458
#
# Epoch 00046: LearningRateScheduler reducing learning rate to tf.Tensor(2.4471761e-05, shape=(), dtype=float32).
# Epoch 46/50
# 60/60 [==============================] - 38s 630ms/step - loss: 0.0493 - dice_loss: 0.0358 - val_loss: 0.0650 - val_dice_loss: 0.0458
#
# Epoch 00047: LearningRateScheduler reducing learning rate to tf.Tensor(1.5708387e-05, shape=(), dtype=float32).
# Epoch 47/50
# 60/60 [==============================] - 38s 631ms/step - loss: 0.0494 - dice_loss: 0.0361 - val_loss: 0.0648 - val_dice_loss: 0.0456
#
# Epoch 00048: LearningRateScheduler reducing learning rate to tf.Tensor(8.856387e-06, shape=(), dtype=float32).
# Epoch 48/50
# 60/60 [==============================] - 38s 631ms/step - loss: 0.0503 - dice_loss: 0.0368 - val_loss: 0.0647 - val_dice_loss: 0.0455
#
# Epoch 00049: LearningRateScheduler reducing learning rate to tf.Tensor(3.9426386e-06, shape=(), dtype=float32).
# Epoch 49/50
# 60/60 [==============================] - 37s 613ms/step - loss: 0.0498 - dice_loss: 0.0364 - val_loss: 0.0648 - val_dice_loss: 0.0456
#
# Epoch 00050: LearningRateScheduler reducing learning rate to tf.Tensor(9.866358e-07, shape=(), dtype=float32).
# Epoch 50/50
# 60/60 [==============================] - 39s 642ms/step - loss: 0.0500 - dice_loss: 0.0365 - val_loss: 0.0645 - val_dice_loss: 0.0453

# %%
# print sample image after training
print_images()

# %%
dice_loss = history.history['dice_loss']
loss = history.history['loss']
val_dice_loss = history.history['val_dice_loss']
val_loss = history.history['val_loss']

epochs_range = range(max_epochs)

plt.figure(figsize=(8, 8))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, loss, label='Loss')
plt.plot(epochs_range, dice_loss, label='Dice Loss')
plt.legend(loc='upper right')
plt.title('Train Loss')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, val_loss, label='Val Loss')
plt.plot(epochs_range, val_dice_loss, label='Val Dice Loss')
plt.legend(loc='upper right')
plt.title('Valid Loss')
plt.show()

# %%
# restoring the latest checkpoint in checkpoint_dir
model.load_weights(checkpoint_dir)

# %%
def mean_iou(y_true, y_pred, num_classes=2):
    # Flatten  
    y_true_f = tf.reshape(y_true, [-1])
    y_pred_f = tf.reshape(y_pred, [-1])

    y_true_f = tf.cast(tf.round(y_true_f), dtype=tf.int32).numpy()
    y_pred_f = tf.cast(tf.round(y_pred_f), dtype=tf.int32).numpy()

    # calculate confusion matrix
    labels = list(range(num_classes))
    current = confusion_matrix(y_true_f, y_pred_f, labels=labels)

    # compute mean iou
    intersection = np.diag(current)
    ground_truth_set = current.sum(axis=1)
    predicted_set = current.sum(axis=0)
    union = ground_truth_set + predicted_set - intersection

    IoU = intersection / union.astype(np.float32)
    return np.mean(IoU)

# %%
mean = []

for images, labels in test_dataset:
    predictions = model(images, training=False)
    m = mean_iou(labels, predictions)
    mean.append(m)

mean = np.array(mean)
mean = np.mean(mean)
print("mean_iou: {}".format(mean))
# Out:
# mean_iou: 0.9389598925776671

# %%
## Define print function
def print_images():
    for test_images, test_labels in test_dataset.take(1):
        predictions = model(test_images, training=False)

        for i in range(batch_size):
            plt.figure(figsize=(10, 20))
            plt.subplot(1, 3, 1)
            plt.imshow(test_images[i,: , :, :])
            plt.title("Input image")

            plt.subplot(1, 3, 2)
            plt.imshow(test_labels[i, :, :, 0])
            plt.title("Actual Mask")

            plt.subplot(1, 3, 3)
            plt.imshow(predictions[i, :, :, 0])
            plt.title("Predicted Mask")
            plt.show()

# %%
print_images()

# %% [markdown]
# ### Step 2. pretrained model을 활용한 U-Net 모델 구성

# %%
vgg16 = tf.keras.applications.VGG16(input_shape=img_shape,
                                         include_top=False,
                                         weights='imagenet')
layer_outputs = [layer.output for layer in vgg16.layers]
layer_outputs
# Out:
# [<tf.Tensor 'input_2:0' shape=(None, 256, 256, 3) dtype=float32>,
#  <tf.Tensor 'block1_conv1/Relu_1:0' shape=(None, 256, 256, 64) dtype=float32>,
#  <tf.Tensor 'block1_conv2/Relu_1:0' shape=(None, 256, 256, 64) dtype=float32>,
#  <tf.Tensor 'block1_pool/MaxPool_1:0' shape=(None, 128, 128, 64) dtype=float32>,
#  <tf.Tensor 'block2_conv1/Relu_1:0' shape=(None, 128, 128, 128) dtype=float32>,
#  <tf.Tensor 'block2_conv2/Relu_1:0' shape=(None, 128, 128, 128) dtype=float32>,
#  <tf.Tensor 'block2_pool/MaxPool_1:0' shape=(None, 64, 64, 128) dtype=float32>,
#  <tf.Tensor 'block3_conv1/Relu_1:0' shape=(None, 64, 64, 256) dtype=float32>,
#  <tf.Tensor 'block3_conv2/Relu_1:0' shape=(None, 64, 64, 256) dtype=float32>,
#  <tf.Tensor 'block3_conv3/Relu_1:0' shape=(None, 64, 64, 256) dtype=float32>,
#  <tf.Tensor 'block3_pool/MaxPool_1:0' shape=(None, 32, 32, 256) dtype=float32>,
#  <tf.Tensor 'block4_conv1/Relu_1:0' shape=(None, 32, 32, 512) dtype=float32>,
#  <tf.Tensor 'block4_conv2/Relu_1:0' shape=(None, 32, 32, 512) dtype=float32>,
#  <tf.Tensor 'block4_conv3/Relu_1:0' shape=(None, 32, 32, 512) dtype=float32>,
#  <tf.Tensor 'block4_pool/MaxPool_1:0' shape=(None, 16, 16, 512) dtype=float32>,
#  <tf.Tensor 'block5_conv1/Relu_1:0' shape=(None, 16, 16, 512) dtype=float32>,
#  <tf.Tensor 'block5_conv2/Relu_1:0' shape=(None, 16, 16, 512) dtype=float32>,
#  <tf.Tensor 'block5_conv3/Relu_1:0' shape=(None, 16, 16, 512) dtype=float32>,
#  <tf.Tensor 'block5_pool/MaxPool_1:0' shape=(None, 8, 8, 512) dtype=float32>]

# %%
class Conv(tf.keras.Model):
    def __init__(self, num_filters, kernel_size):
        super(Conv, self).__init__()
        self.conv = layers.Conv2D(num_filters, kernel_size, padding='same')
        self.bn = layers.BatchNormalization()

    def call(self, inputs, training=True):
        x = self.conv(inputs)
        x = self.bn(x, training=training)
        x = layers.ReLU()(x)

        return x

# %%
class ConvBlock(tf.keras.Model):
    def __init__(self, num_filters):
        super(ConvBlock, self).__init__()
        self.conv1 = Conv(num_filters, 3)
        self.conv2 = Conv(num_filters * 2, 3)

    def call(self, inputs, training=True):
        encoder = self.conv1(inputs, training=training)
        encoder = self.conv2(encoder, training=training)

        return encoder

class ConvBlock_R(tf.keras.Model):
    def __init__(self, num_filters):
        super(ConvBlock_R, self).__init__()
        self.conv1 = Conv(num_filters, 3)
        self.conv2 = Conv(num_filters, 3)

    def call(self, inputs, training=True):
        decoder = self.conv1(inputs, training=training)
        decoder = self.conv2(decoder, training=training)

        return decoder

class EncoderBlock(tf.keras.Model):
    def __init__(self, num_filters):
        super(EncoderBlock, self).__init__()
        self.conv_block = ConvBlock(num_filters)
        self.encoder_pool = layers.MaxPool2D()

    def call(self, inputs, training=True):
        encoder = self.conv_block(inputs, training=training)
        encoder_pool = self.encoder_pool(encoder)

        return encoder_pool, encoder


class DecoderBlock(tf.keras.Model):
    def __init__(self, num_filters):
        super(DecoderBlock, self).__init__()
        self.convT = layers.Conv2DTranspose(num_filters, 3, strides=2, padding='same')
        self.bn = layers.BatchNormalization()
        self.conv_block_r = ConvBlock_R(num_filters)

    def call(self, input_tensor, concat_tensor, training=True):
        decoder = self.convT(input_tensor)            
        decoder = self.bn(decoder, training=training)
        decoder = layers.ReLU()(decoder)
        decoder = tf.concat([decoder, concat_tensor], axis=-1)
        decoder = self.conv_block_r(decoder, training=training)

        return decoder

# %%
class Vgg16UNet(tf.keras.Model):
    def __init__(self):
        super(Vgg16UNet, self).__init__()
        self.vgg16 = tf.keras.applications.VGG16(input_shape=img_shape,
                                         include_top=False,
                                         weights='imagenet')
        layer_outputs = [layer.output for layer in self.vgg16.layers]
        self.vgg16_act = models.Model(inputs=self.vgg16.input, 
                                      outputs=[layer_outputs[2], 
                                               layer_outputs[5], 
                                               layer_outputs[9], 
                                               layer_outputs[13], 
                                               layer_outputs[17]])


        self.center = ConvBlock(1024)

        self.decoder_block4 = DecoderBlock(512)
        self.decoder_block3 = DecoderBlock(256)
        self.decoder_block2 = DecoderBlock(128)
        self.decoder_block1 = DecoderBlock(64)

        self.output_conv = layers.Conv2D(1, 1, activation='sigmoid')

    def call(self, inputs, training=True):

        encoder1, encoder2, encoder3, encoder4, center = self.vgg16_act(inputs) 

        decoder4 = self.decoder_block4(center, encoder4)
        decoder3 = self.decoder_block3(decoder4, encoder3)
        decoder2 = self.decoder_block2(decoder3, encoder2)
        decoder1 = self.decoder_block1(decoder2, encoder1)
        
        outputs = self.output_conv(decoder1)

        return outputs

# %%
vgg16Unet_model = Vgg16UNet()

# %%
def dice_coeff(y_true, y_pred):
    smooth = 1e-10
    # Flatten
    y_true_f = tf.reshape(y_true, [-1])
    y_pred_f = tf.reshape(y_pred, [-1])
    intersection = tf.reduce_sum(y_true_f * y_pred_f)
    score = (2. * intersection + smooth) / (tf.reduce_sum(tf.square(y_true_f)) + \
                                            tf.reduce_sum(tf.square(y_pred_f)) + smooth)

    return score

# %%
def dice_loss(y_true, y_pred):
    loss = 1 - dice_coeff(y_true, y_pred)
    return loss

# %%
def bce_dice_loss(y_true, y_pred):
    loss = tf.reduce_mean(losses.binary_crossentropy(y_true, y_pred)) + \
          dice_loss(y_true, y_pred)
    return loss

# %%
optimizer = tf.keras.optimizers.Adam() # 기본 Learning rate 사용

# %%
# 위에서 구성한 두가지 모델 중에서 하나를 선택해 주세요. 
# 여기서 선택을 바꾸어 다른 모델의 학습도 진행해 볼 수 있습니다. 

#print('select the Encoder-Decoder model')
#model = ed_model
#checkpoint_dir =os.path.join(DATASET_PATH,'train_ckpt/ed_model')

#print('select the U-Net model')
#model = unet_model
#checkpoint_dir =os.path.join(DATASET_PATH,'train_ckpt/unet_model')

print('select the VGG16U-Net model')
model = vgg16Unet_model
checkpoint_dir =os.path.join(DATASET_PATH,'train_ckpt/vgg16unet_model')
# Out:
# select the VGG16U-Net model

# %% [markdown]
# ### Step 3. 학습과 테스트, 시각화

# %%
model.compile(optimizer=optimizer, loss=bce_dice_loss, metrics=[dice_loss])
predictions = model(tf.random.normal([batch_size, image_size, image_size, 3]))
print(predictions.shape)
# Out:
# (8, 256, 256, 1)

# %%
model.summary()
# Out:
# Model: "vgg16u_net_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# vgg16 (Functional)           (None, 8, 8, 512)         14714688
# _________________________________________________________________
# functional_7 (Functional)    [(None, 256, 256, 64), (N 14714688
# _________________________________________________________________
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-40-5f15418b3570> in <module>
# ----> 1 model.summary()
#
# ~/anaconda3/envs/aiffel/lib/python3.7/site-packages/tensorflow/python/keras/engine/training.py in summary(self, line_length, positions, print_fn)
#    2357                               line_length=line_length,
#    2358                               positions=positions,
# -> 2359                               print_fn=print_fn)
#    2360
#    2361   @property
#
# ~/anaconda3/envs/aiffel/lib/python3.7/site-packages/tensorflow/python/keras/utils/layer_utils.py in print_summary(model, line_length, positions, print_fn)
#     251   for i in range(len(layers)):
#     252     if sequential_like:
# --> 253       print_layer_summary(layers[i])
#     254     else:
#     255       print_layer_summary_with_connections(layers[i])
#
# ~/anaconda3/envs/aiffel/lib/python3.7/site-packages/tensorflow/python/keras/utils/layer_utils.py in print_layer_summary(layer)
#     209     name = layer.name
#     210     cls_name = layer.__class__.__name__
# --> 211     fields = [name + ' (' + cls_name + ')', output_shape, layer.count_params()]
#     212     print_row(fields, positions)
#     213
#
# ~/anaconda3/envs/aiffel/lib/python3.7/site-packages/tensorflow/python/keras/engine/base_layer.py in count_params(self)
#    2157                          ', but the layer isn\'t built. '
#    2158                          'You can build it manually via: `' + self.name +
# -> 2159                          '.build(batch_input_shape)`.')
#    2160     return layer_utils.count_params(self.weights)
#    2161
#
# ValueError: You tried to call `count_params` on conv_block_2, but the layer isn't built. You can build it manually via: `conv_block_2.build(batch_input_shape)`.

# %%
if not os.path.isdir(checkpoint_dir):
    os.makedirs(checkpoint_dir)

cp_callback = tf.keras.callbacks.ModelCheckpoint(checkpoint_dir,
                                                 save_weights_only=True,
                                                 monitor='val_loss',
                                                 mode='auto',
                                                 save_best_only=True,
                                                 verbose=0)

# %%
cos_decay = tf.keras.experimental.CosineDecay(1e-3, 
                                              max_epochs)
lr_callback = tf.keras.callbacks.LearningRateScheduler(cos_decay, verbose=1)

# %%
## Define print function
def print_images():
    for test_images, test_labels in test_dataset.take(1):
        predictions = model(test_images, training=False)

        plt.figure(figsize=(10, 20))
        plt.subplot(1, 3, 1)
        plt.imshow(test_images[0,: , :, :])
        plt.title("Input image")

        plt.subplot(1, 3, 2)
        plt.imshow(test_labels[0, :, :, 0])
        plt.title("Actual Mask")

        plt.subplot(1, 3, 3)
        plt.imshow(predictions[0, :, :, 0])
        plt.title("Predicted Mask")
        plt.show()

# %%
history = model.fit(train_dataset,
                    epochs=max_epochs,    # 50
                    steps_per_epoch=num_train_examples//batch_size,
                    validation_data=test_dataset,
                    validation_steps=num_test_examples//batch_size,
                    callbacks=[cp_callback, lr_callback]
                    )
# Out:
# Epoch 00001: LearningRateScheduler reducing learning rate to tf.Tensor(0.001, shape=(), dtype=float32).
# Epoch 1/50
#  2/60 [>.............................] - ETA: 11s - loss: 1.5644 - dice_loss: 0.8336WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.1550s vs `on_train_batch_end` time: 0.2382s). Check your callbacks.
# 60/60 [==============================] - ETA: 0s - loss: 0.8897 - dice_loss: 0.6247WARNING:tensorflow:Callbacks method `on_test_batch_end` is slow compared to the batch time (batch time: 0.0026s vs `on_test_batch_end` time: 0.1187s). Check your callbacks.
# 60/60 [==============================] - 24s 407ms/step - loss: 0.8897 - dice_loss: 0.6247 - val_loss: 7.8428 - val_dice_loss: 0.8680
#
# Epoch 00002: LearningRateScheduler reducing learning rate to tf.Tensor(0.0009990134, shape=(), dtype=float32).
# Epoch 2/50
# 60/60 [==============================] - 24s 396ms/step - loss: 0.6905 - dice_loss: 0.5186 - val_loss: 1.4654 - val_dice_loss: 0.7546
#
# Epoch 00003: LearningRateScheduler reducing learning rate to tf.Tensor(0.0009960574, shape=(), dtype=float32).
# Epoch 3/50
# 60/60 [==============================] - 24s 400ms/step - loss: 0.5988 - dice_loss: 0.4534 - val_loss: 1.3075 - val_dice_loss: 0.7025
#
# Epoch 00004: LearningRateScheduler reducing learning rate to tf.Tensor(0.0009911436, shape=(), dtype=float32).
# Epoch 4/50
# 60/60 [==============================] - 24s 400ms/step - loss: 0.5121 - dice_loss: 0.3866 - val_loss: 0.8210 - val_dice_loss: 0.6558
#
# Epoch 00005: LearningRateScheduler reducing learning rate to tf.Tensor(0.0009842915, shape=(), dtype=float32).
# Epoch 5/50
# 60/60 [==============================] - 24s 400ms/step - loss: 0.4438 - dice_loss: 0.3330 - val_loss: 0.6316 - val_dice_loss: 0.4522
#
# Epoch 00006: LearningRateScheduler reducing learning rate to tf.Tensor(0.00097552827, shape=(), dtype=float32).
# Epoch 6/50
# 60/60 [==============================] - 24s 400ms/step - loss: 0.4138 - dice_loss: 0.3102 - val_loss: 0.6219 - val_dice_loss: 0.4625
#
# Epoch 00007: LearningRateScheduler reducing learning rate to tf.Tensor(0.00096488826, shape=(), dtype=float32).
# Epoch 7/50
# 60/60 [==============================] - 24s 401ms/step - loss: 0.3367 - dice_loss: 0.2511 - val_loss: 0.4450 - val_dice_loss: 0.3079
#
# Epoch 00008: LearningRateScheduler reducing learning rate to tf.Tensor(0.0009524136, shape=(), dtype=float32).
# Epoch 8/50
# 60/60 [==============================] - 24s 401ms/step - loss: 0.3131 - dice_loss: 0.2330 - val_loss: 0.4432 - val_dice_loss: 0.3368
#
# Epoch 00009: LearningRateScheduler reducing learning rate to tf.Tensor(0.00093815336, shape=(), dtype=float32).
# Epoch 9/50
# 60/60 [==============================] - 24s 402ms/step - loss: 0.2601 - dice_loss: 0.1917 - val_loss: 0.2742 - val_dice_loss: 0.1995
#
# Epoch 00010: LearningRateScheduler reducing learning rate to tf.Tensor(0.000922164, shape=(), dtype=float32).
# Epoch 10/50
# 60/60 [==============================] - 24s 393ms/step - loss: 0.2856 - dice_loss: 0.2121 - val_loss: 0.3862 - val_dice_loss: 0.2957
#
# Epoch 00011: LearningRateScheduler reducing learning rate to tf.Tensor(0.0009045085, shape=(), dtype=float32).
# Epoch 11/50
# 60/60 [==============================] - 24s 401ms/step - loss: 0.2272 - dice_loss: 0.1669 - val_loss: 0.2347 - val_dice_loss: 0.1690
#
# Epoch 00012: LearningRateScheduler reducing learning rate to tf.Tensor(0.0008852567, shape=(), dtype=float32).
# Epoch 12/50
# 60/60 [==============================] - 24s 393ms/step - loss: 0.2081 - dice_loss: 0.1531 - val_loss: 0.2947 - val_dice_loss: 0.2032
#
# Epoch 00013: LearningRateScheduler reducing learning rate to tf.Tensor(0.00086448435, shape=(), dtype=float32).
# Epoch 13/50
# 60/60 [==============================] - 24s 401ms/step - loss: 0.1935 - dice_loss: 0.1423 - val_loss: 0.2195 - val_dice_loss: 0.1613
#
# Epoch 00014: LearningRateScheduler reducing learning rate to tf.Tensor(0.00084227364, shape=(), dtype=float32).
# Epoch 14/50
# 60/60 [==============================] - 24s 406ms/step - loss: 0.2014 - dice_loss: 0.1486 - val_loss: 0.1891 - val_dice_loss: 0.1325
#
# Epoch 00015: LearningRateScheduler reducing learning rate to tf.Tensor(0.00081871205, shape=(), dtype=float32).
# Epoch 15/50
# 60/60 [==============================] - 24s 403ms/step - loss: 0.1433 - dice_loss: 0.1037 - val_loss: 0.1689 - val_dice_loss: 0.1272
#
# Epoch 00016: LearningRateScheduler reducing learning rate to tf.Tensor(0.00079389266, shape=(), dtype=float32).
# Epoch 16/50
# 60/60 [==============================] - 26s 431ms/step - loss: 0.1490 - dice_loss: 0.1081 - val_loss: 0.1642 - val_dice_loss: 0.1200
#
# Epoch 00017: LearningRateScheduler reducing learning rate to tf.Tensor(0.00076791336, shape=(), dtype=float32).
# Epoch 17/50
# 60/60 [==============================] - 24s 394ms/step - loss: 0.1446 - dice_loss: 0.1052 - val_loss: 0.2220 - val_dice_loss: 0.1691
#
# Epoch 00018: LearningRateScheduler reducing learning rate to tf.Tensor(0.0007408768, shape=(), dtype=float32).
# Epoch 18/50
# 60/60 [==============================] - 24s 399ms/step - loss: 0.1369 - dice_loss: 0.0996 - val_loss: 0.1488 - val_dice_loss: 0.1056
#
# Epoch 00019: LearningRateScheduler reducing learning rate to tf.Tensor(0.00071288965, shape=(), dtype=float32).
# Epoch 19/50
# 60/60 [==============================] - 23s 389ms/step - loss: 0.1194 - dice_loss: 0.0865 - val_loss: 0.3009 - val_dice_loss: 0.2291
#
# Epoch 00020: LearningRateScheduler reducing learning rate to tf.Tensor(0.00068406225, shape=(), dtype=float32).
# Epoch 20/50
# 60/60 [==============================] - 24s 397ms/step - loss: 0.1412 - dice_loss: 0.1039 - val_loss: 0.1033 - val_dice_loss: 0.0739
#
# Epoch 00021: LearningRateScheduler reducing learning rate to tf.Tensor(0.0006545085, shape=(), dtype=float32).
# Epoch 21/50
# 60/60 [==============================] - 23s 390ms/step - loss: 0.0976 - dice_loss: 0.0706 - val_loss: 0.1518 - val_dice_loss: 0.1093
#
# Epoch 00022: LearningRateScheduler reducing learning rate to tf.Tensor(0.00062434503, shape=(), dtype=float32).
# Epoch 22/50
# 60/60 [==============================] - 23s 389ms/step - loss: 0.1025 - dice_loss: 0.0742 - val_loss: 0.1062 - val_dice_loss: 0.0748
#
# Epoch 00023: LearningRateScheduler reducing learning rate to tf.Tensor(0.00059369067, shape=(), dtype=float32).
# Epoch 23/50
# 60/60 [==============================] - 23s 389ms/step - loss: 0.0887 - dice_loss: 0.0643 - val_loss: 0.1335 - val_dice_loss: 0.0993
#
# Epoch 00024: LearningRateScheduler reducing learning rate to tf.Tensor(0.00056266657, shape=(), dtype=float32).
# Epoch 24/50
# 60/60 [==============================] - 23s 390ms/step - loss: 0.0867 - dice_loss: 0.0629 - val_loss: 0.1753 - val_dice_loss: 0.1246
#
# Epoch 00025: LearningRateScheduler reducing learning rate to tf.Tensor(0.00053139526, shape=(), dtype=float32).
# Epoch 25/50
# 60/60 [==============================] - 24s 398ms/step - loss: 0.0843 - dice_loss: 0.0608 - val_loss: 0.0975 - val_dice_loss: 0.0704
#
# Epoch 00026: LearningRateScheduler reducing learning rate to tf.Tensor(0.00049999997, shape=(), dtype=float32).
# Epoch 26/50
# 60/60 [==============================] - 24s 398ms/step - loss: 0.0837 - dice_loss: 0.0608 - val_loss: 0.0959 - val_dice_loss: 0.0689
#
# Epoch 00027: LearningRateScheduler reducing learning rate to tf.Tensor(0.0004686048, shape=(), dtype=float32).
# Epoch 27/50
# 60/60 [==============================] - 24s 397ms/step - loss: 0.0709 - dice_loss: 0.0513 - val_loss: 0.0721 - val_dice_loss: 0.0511
#
# Epoch 00028: LearningRateScheduler reducing learning rate to tf.Tensor(0.00043733336, shape=(), dtype=float32).
# Epoch 28/50
# 60/60 [==============================] - 23s 390ms/step - loss: 0.0703 - dice_loss: 0.0511 - val_loss: 0.1194 - val_dice_loss: 0.0866
#
# Epoch 00029: LearningRateScheduler reducing learning rate to tf.Tensor(0.00040630935, shape=(), dtype=float32).
# Epoch 29/50
# 60/60 [==============================] - 24s 399ms/step - loss: 0.0694 - dice_loss: 0.0501 - val_loss: 0.0665 - val_dice_loss: 0.0475
#
# Epoch 00030: LearningRateScheduler reducing learning rate to tf.Tensor(0.00037565507, shape=(), dtype=float32).
# Epoch 30/50
# 60/60 [==============================] - 24s 398ms/step - loss: 0.0596 - dice_loss: 0.0430 - val_loss: 0.0654 - val_dice_loss: 0.0467
#
# Epoch 00031: LearningRateScheduler reducing learning rate to tf.Tensor(0.00034549143, shape=(), dtype=float32).
# Epoch 31/50
# 60/60 [==============================] - 24s 398ms/step - loss: 0.0614 - dice_loss: 0.0448 - val_loss: 0.0645 - val_dice_loss: 0.0463
#
# Epoch 00032: LearningRateScheduler reducing learning rate to tf.Tensor(0.0003159377, shape=(), dtype=float32).
# Epoch 32/50
# 60/60 [==============================] - 24s 398ms/step - loss: 0.0554 - dice_loss: 0.0400 - val_loss: 0.0595 - val_dice_loss: 0.0424
#
# Epoch 00033: LearningRateScheduler reducing learning rate to tf.Tensor(0.00028711034, shape=(), dtype=float32).
# Epoch 33/50
# 60/60 [==============================] - 23s 390ms/step - loss: 0.0556 - dice_loss: 0.0402 - val_loss: 0.0744 - val_dice_loss: 0.0536
#
# Epoch 00034: LearningRateScheduler reducing learning rate to tf.Tensor(0.0002591231, shape=(), dtype=float32).
# Epoch 34/50
# 60/60 [==============================] - 24s 399ms/step - loss: 0.0553 - dice_loss: 0.0401 - val_loss: 0.0575 - val_dice_loss: 0.0412
#
# Epoch 00035: LearningRateScheduler reducing learning rate to tf.Tensor(0.00023208655, shape=(), dtype=float32).
# Epoch 35/50
# 60/60 [==============================] - 23s 390ms/step - loss: 0.0553 - dice_loss: 0.0407 - val_loss: 0.0648 - val_dice_loss: 0.0465
#
# Epoch 00036: LearningRateScheduler reducing learning rate to tf.Tensor(0.00020610739, shape=(), dtype=float32).
# Epoch 36/50
# 60/60 [==============================] - 23s 390ms/step - loss: 0.0516 - dice_loss: 0.0375 - val_loss: 0.0636 - val_dice_loss: 0.0460
#
# Epoch 00037: LearningRateScheduler reducing learning rate to tf.Tensor(0.00018128792, shape=(), dtype=float32).
# Epoch 37/50
# 60/60 [==============================] - 23s 390ms/step - loss: 0.0544 - dice_loss: 0.0399 - val_loss: 0.0809 - val_dice_loss: 0.0590
#
# Epoch 00038: LearningRateScheduler reducing learning rate to tf.Tensor(0.00015772645, shape=(), dtype=float32).
# Epoch 38/50
# 60/60 [==============================] - 23s 389ms/step - loss: 0.0502 - dice_loss: 0.0361 - val_loss: 0.0622 - val_dice_loss: 0.0448
#
# Epoch 00039: LearningRateScheduler reducing learning rate to tf.Tensor(0.0001355157, shape=(), dtype=float32).
# Epoch 39/50
# 60/60 [==============================] - 24s 399ms/step - loss: 0.0492 - dice_loss: 0.0356 - val_loss: 0.0569 - val_dice_loss: 0.0405
#
# Epoch 00040: LearningRateScheduler reducing learning rate to tf.Tensor(0.00011474339, shape=(), dtype=float32).
# Epoch 40/50
# 60/60 [==============================] - 24s 398ms/step - loss: 0.0474 - dice_loss: 0.0343 - val_loss: 0.0555 - val_dice_loss: 0.0395
#
# Epoch 00041: LearningRateScheduler reducing learning rate to tf.Tensor(9.54915e-05, shape=(), dtype=float32).
# Epoch 41/50
# 60/60 [==============================] - 24s 397ms/step - loss: 0.0458 - dice_loss: 0.0329 - val_loss: 0.0553 - val_dice_loss: 0.0393
#
# Epoch 00042: LearningRateScheduler reducing learning rate to tf.Tensor(7.783601e-05, shape=(), dtype=float32).
# Epoch 42/50
# 60/60 [==============================] - 23s 390ms/step - loss: 0.0460 - dice_loss: 0.0332 - val_loss: 0.0568 - val_dice_loss: 0.0404
#
# Epoch 00043: LearningRateScheduler reducing learning rate to tf.Tensor(6.184671e-05, shape=(), dtype=float32).
# Epoch 43/50
# 60/60 [==============================] - 24s 398ms/step - loss: 0.0446 - dice_loss: 0.0322 - val_loss: 0.0549 - val_dice_loss: 0.0390
#
# Epoch 00044: LearningRateScheduler reducing learning rate to tf.Tensor(4.7586444e-05, shape=(), dtype=float32).
# Epoch 44/50
# 60/60 [==============================] - 24s 398ms/step - loss: 0.0447 - dice_loss: 0.0324 - val_loss: 0.0541 - val_dice_loss: 0.0384
#
# Epoch 00045: LearningRateScheduler reducing learning rate to tf.Tensor(3.5111727e-05, shape=(), dtype=float32).
# Epoch 45/50
# 60/60 [==============================] - 24s 402ms/step - loss: 0.0438 - dice_loss: 0.0315 - val_loss: 0.0541 - val_dice_loss: 0.0383
#
# Epoch 00046: LearningRateScheduler reducing learning rate to tf.Tensor(2.4471761e-05, shape=(), dtype=float32).
# Epoch 46/50
# 60/60 [==============================] - 25s 412ms/step - loss: 0.0445 - dice_loss: 0.0322 - val_loss: 0.0545 - val_dice_loss: 0.0387
#
# Epoch 00047: LearningRateScheduler reducing learning rate to tf.Tensor(1.5708387e-05, shape=(), dtype=float32).
# Epoch 47/50
# 60/60 [==============================] - 24s 395ms/step - loss: 0.0444 - dice_loss: 0.0323 - val_loss: 0.0545 - val_dice_loss: 0.0387
#
# Epoch 00048: LearningRateScheduler reducing learning rate to tf.Tensor(8.856387e-06, shape=(), dtype=float32).
# Epoch 48/50
# 60/60 [==============================] - 24s 395ms/step - loss: 0.0442 - dice_loss: 0.0320 - val_loss: 0.0544 - val_dice_loss: 0.0385
#
# Epoch 00049: LearningRateScheduler reducing learning rate to tf.Tensor(3.9426386e-06, shape=(), dtype=float32).
# Epoch 49/50
# 60/60 [==============================] - 24s 394ms/step - loss: 0.0434 - dice_loss: 0.0315 - val_loss: 0.0542 - val_dice_loss: 0.0384
#
# Epoch 00050: LearningRateScheduler reducing learning rate to tf.Tensor(9.866358e-07, shape=(), dtype=float32).
# Epoch 50/50
# 60/60 [==============================] - 24s 394ms/step - loss: 0.0434 - dice_loss: 0.0314 - val_loss: 0.0542 - val_dice_loss: 0.0384

# %%
# print sample image after training
print_images()

# %% [markdown]
# ### Step4. 모델 성능 비교분석

# %%
dice_loss = history.history['dice_loss']
loss = history.history['loss']
val_dice_loss = history.history['val_dice_loss']
val_loss = history.history['val_loss']

epochs_range = range(max_epochs)

plt.figure(figsize=(8, 8))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, loss, label='Loss')
plt.plot(epochs_range, dice_loss, label='Dice Loss')
plt.legend(loc='upper right')
plt.title('Train Loss')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, val_loss, label='Val Loss')
plt.plot(epochs_range, val_dice_loss, label='Val Dice Loss')
plt.legend(loc='upper right')
plt.title('Valid Loss')
plt.show()

# %%
# restoring the latest checkpoint in checkpoint_dir
model.load_weights(checkpoint_dir)

# %%
def mean_iou(y_true, y_pred, num_classes=2):
    # Flatten  
    y_true_f = tf.reshape(y_true, [-1])
    y_pred_f = tf.reshape(y_pred, [-1])

    y_true_f = tf.cast(tf.round(y_true_f), dtype=tf.int32).numpy()
    y_pred_f = tf.cast(tf.round(y_pred_f), dtype=tf.int32).numpy()

    # calculate confusion matrix
    labels = list(range(num_classes))
    current = confusion_matrix(y_true_f, y_pred_f, labels=labels)

    # compute mean iou
    intersection = np.diag(current)
    ground_truth_set = current.sum(axis=1)
    predicted_set = current.sum(axis=0)
    union = ground_truth_set + predicted_set - intersection

    IoU = intersection / union.astype(np.float32)
    return np.mean(IoU)

# %%
mean = []

for images, labels in test_dataset:
    predictions = model(images, training=False)
    m = mean_iou(labels, predictions)
    mean.append(m)

mean = np.array(mean)
mean = np.mean(mean)
print("mean_iou: {}".format(mean))
# Out:
# mean_iou: 0.9460774599092602

# %%
## Define print function
def print_images():
    for test_images, test_labels in test_dataset.take(1):
        predictions = model(test_images, training=False)

        for i in range(batch_size):
            plt.figure(figsize=(10, 20))
            plt.subplot(1, 3, 1)
            plt.imshow(test_images[i,: , :, :])
            plt.title("Input image")

            plt.subplot(1, 3, 2)
            plt.imshow(test_labels[i, :, :, 0])
            plt.title("Actual Mask")

            plt.subplot(1, 3, 3)
            plt.imshow(predictions[i, :, :, 0])
            plt.title("Predicted Mask")
            plt.show()

# %%
print_images()

# %% [markdown]
# - 기존 (mean_iou: 0.9389598925776671) 대비 개선된 것을 확인. (mean_iou: 0.9460774599092602)
